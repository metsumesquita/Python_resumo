# %% [markdown]
# <a href="https://colab.research.google.com/github/metsumesquita/Python_resumo/blob/main/modulos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %%
#usando funçoes
def fatorial(numero):
  if numero==0 or numero==1:
    return 1
  resultado=1
  for i in range(2,numero+1):
    resultado*=i
  return resultado
print(fatorial(5))

# %%
#utilizand a biblioteca math, chamando a funçao fatorial

math.factorial(5)

# %%
beans_values=[10,8,12,15,17,6,9]

mean = sum(beans_values)/len(beans_values)

print("A média é {r:.2f}".format(r=mean))

# %%
#desvio padrao
soma = 0

for valor_atual in beans_values:
    diferença = valor_atual - mean
    soma += diferença ** 2

desvio_padrao = math.sqrt(soma / len(beans_values))

print("O desvio padrão populacional é {r:.2f}".format(r=desvio_padrao))

# %% [markdown]
# #modulo numpy

# %%
# Import the numpy package as np
import numpy as np

baseball = [180, 215, 210, 210, 188, 176, 209, 200]

# Create a numpy array from baseball: np_baseball
np_baseball=np.array(baseball)
print(np_baseball)

# %%
# Import numpy
import numpy as np

# Create a numpy array from height_in: np_height_in
height_in=[]
np_height_in=np.array(height_in)
print(np_height_in)
np_height_m=np_height_in*0.0254
print(np_height_m)
weight_lb=[]
np_weight_lb = np.array(weight_lb)
np_height_in = np.array(height_in)

# Print out the weight at index 50
print(np_weight_lb[50])
#do 100 ate o 110 , como começamos com 0 precisamos ir ate i+1
print(np_height_in[100:111])

# %%
import numpy as np

vetores= [[12,24,48],
            [12,6,12],
            [2,6,3],
            [6,3,24]]
NumPy_array_name=np.array(vetores)

#selecionando uma coluna
#usando fatiamento
print(NumPy_array_name[:, 2])

# %%
#selecionando uma linha
#usando fatiamento
print(NumPy_array_name[0,:])

# %%
import numpy as np

baseball = [[180, 78.4],
            [215, 102.7],
            [210, 98.5],
            [188, 75.2],
            [180, 78.4],
            [215, 102.7],
            [210, 98.5],
            [188, 75.2],
            [180, 78.4],
            [215, 102.7],
            [210, 98.5],
            [188, 75.2],
            [180, 78.4],
            [215, 102.7],
            [210, 98.5],
            [188, 75.2]
            ]

# Create a 2D numpy array from baseball: np_baseball
np_baseball=np.array(baseball)
#tipo do dado
print(type(np_baseball))
#formato
print(np_baseball.shape)

# Print out the 13th row of np_baseball
#Prints the entire 13th row (index 12.
#Because arrays use \(0\)-based indexing, 12 gets the \(13^{\text{th}}\) player.
print(np_baseball[12,:])


# Create np_height_in and np_weight_lb from np_baseball
np_height_in=(np_baseball[:,0])
np_weight_lb=(np_baseball[:,1])

# Print out height of 16th player

print(np_baseball[15,0])
# Out:
# <class 'numpy.ndarray'>
# (16, 2)
# [180.   78.4]
# [ 78.4 102.7  98.5  75.2  78.4 102.7  98.5  75.2  78.4 102.7  98.5  75.2
#   78.4 102.7  98.5  75.2]
# [215.  102.7]
# 188.0

# %%
np_baseball = np.array(baseball)

# Print out addition of np_baseball and updated
print(np_baseball+updated)
conversion=[[0.0254,0.453592,1]]
# Create numpy array: conversion
multiple=conversion*np_baseball
print(multiple)

# %%
avg = np.mean(np_baseball[:,0])
print("Average: " + str(avg))

# Print median height
med = np.median(np_baseball[:,0])
print("Median: " + str(med))

# Print out the standard deviation on height
stddev = np.std(np_baseball[:,0])
print("Standard Deviation: " + str(stddev))

# Print out correlation between first and second column
corr = np.corrcoef(np_baseball[:,0],np_baseball[:,1])
print("Correlation: " + str(corr))

# %%
#esse exemplo se repete 10 vezes
#pq no range tem o valor 10

class entrada:
    def valida_inteiro(mensagem, minimo, maximo):
        while True:
            try:
                v = int(input(mensagem))
                if  v >= minimo and v<= maximo: # Simplificado
                    return v
                else:
                    print(f"Digite um valor entre {minimo} e {maximo}")
            except ValueError:
                print("Você deve digitar um número inteiro")

L = []

for x in range(10):
    # Corrigido para append e ajustado para acessar a classe entrada corretamente
    L.append(entrada.valida_inteiro("Digite um número inteiro: ", 0, 30))

print("A soma é: " + str(sum(L)))
# Out:
# Digite um número inteiro: 10
# Digite um número inteiro: 10
# Digite um número inteiro: 10
# Digite um número inteiro: 10
# Digite um número inteiro: 10
# Digite um número inteiro: 10
# Digite um número inteiro: 10
# Digite um número inteiro: 10
# Digite um número inteiro: 10
# Digite um número inteiro: 10
# A soma é: 100

# %% [markdown]
# #lib random

# %%
import random
for x in range(5):
  print(random.randint(1,100))
# Out:
# 53
# 63
# 17
# 74
# 31

# %%
import random

random.seed(10)
print(random.random())

# %%
import random

mylist = ["apple", "banana", "cherry"]

print(random.choice(mylist))
